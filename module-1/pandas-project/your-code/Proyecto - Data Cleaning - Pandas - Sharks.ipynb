# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
shark_attack = pd.read_csv(r'/Users/Menazina/Desktop/ironhack/datamex_082020/module-1/pandas-project/your-code/attacks_shark.csv', engine = 'python', sep=',')

# %% [markdown]
# Checar que se importo correctamente nuestra base de datos:

# %%
shark_attack
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %% [markdown]
# Copiarla en caso que tengamos que regresar a nuestra de datos original.

# %%
shark_attack_2 = shark_attack.copy()

# %%
shark_attack_2
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
shark_attack_2.shape
# Out:
# (25723, 24)

# %%
shark_attack_2.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson�McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
shark_attack_2.drop_duplicates(keep = "first", inplace = True)

# %%
shark_attack_2
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
shark_attack_2.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6307            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6308            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6309            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8702          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 6307   ...      NaN                    NaN  NaN          NaN  NaN
# 6308   ...      NaN                    NaN  NaN          NaN  NaN
# 6309   ...      NaN                    NaN  NaN          NaN  NaN
# 8702   ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %%
columns_compare = shark_attack_2.columns.values
columns_compare = np.delete(columns_compare,(0,21))
shark_attack_2.drop_duplicates(columns_compare, keep = "first", inplace = True)

# %%
shark_attack_2
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
# 6302           0          NaN     NaN         NaN                 NaN
#
#                    Area                             Location      Activity  \
# ...

# %%
shark_attack_2.drop(len(shark_attack_2)-1, axis = 0, inplace = True)

# %%
shark_attack_2
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
shark_attack_2["Year"].dtype
# Out:
# dtype('float64')

# %%
shark_attack_2[shark_attack_2["Year"].isnull()]
# Out:
#        Case Number                  Date  Year        Type    Country  \
# 187   2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA
# 6079  1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex   ...  \
# 187   Queensland         NaN  Spearfishing  Kerry Daniel    M  ...
# 6079  Cumberland  Whitehaven      Swimming         a boy    M  ...
#
#         Species   Investigator or Source                           pdf  \
# 187   Bull shark  Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf
# 6079         NaN          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                            href formula  \
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6079  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.01.08.R
# ...

# %%
indice = shark_attack_2["Year"][shark_attack_2["Year"] == 0].index
for i in indice:
    indice_mod = shark_attack_2["Date"][i]
    try:
        shark_attack_2["Year"][i] = float(indice_mod[-4:])
    except: 
        shark_attack_2["Year"][i] = "Not Registered Year"
# Out:
# /Users/Menazina/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/Menazina/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/Menazina/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
shark_attack_2
# Out:
#      Case Number         Date  Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903  1903  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  1905  Unprovoked                 USA
# 6300     ND.0002    1883-1889  1889  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  1853  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
shark_attack_2[shark_attack_2["Year"] == "Not Registered Year"]
# Out:
#      Case Number                 Date                 Year          Type  \
# 6177   0000.0214         Ca. 214 B.C.  Not Registered Year    Unprovoked
# 6178   0000.0336        Ca. 336.B.C..  Not Registered Year    Unprovoked
# 6179   0000.0493             493 B.C.  Not Registered Year  Sea Disaster
# 6180   0000.0725         Ca. 725 B.C.  Not Registered Year  Sea Disaster
# 6187     ND-0148                2009?  Not Registered Year    Unprovoked
# 6209     ND.0110  No date, late 1960s  Not Registered Year    Unprovoked
# 6214     ND.0104                1950s  Not Registered Year    Unprovoked
# 6216     ND.0100                2003?  Not Registered Year    Unprovoked
# 6217     ND.0097              No date  Not Registered Year    Unprovoked
# 6218     ND.0096              No date  Not Registered Year    Unprovoked
# 6241     ND.0065                1960s  Not Registered Year    Unprovoked
# 6242     ND.0064                1960s  Not Registered Year    Unprovoked
# ...

# %%
shark_attack_2["Type"].value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
shark_attack_2["Type"].isnull().sum()
# Out:
# 4

# %%
shark_attack_2[shark_attack_2["Type"].isnull()]
# Out:
#        Case Number                  Date  Year Type    Country           Area  \
# 85    2017.09.15.a           15-Sep-2017  2017  NaN      SAMOA   Upolu Island
# 382     2015.07.27           27-Jul-2015  2015  NaN  AUSTRALIA       Victoria
# 4867  1936.09.11.R  Reported 11-Sep-1936  1936  NaN    VIETNAM            NaN
# 5705  1890.03.03.R  Reported 03-Mar-1890  1890  NaN     CEYLON            NaN
#
#               Location           Activity           Name Sex   ... Species   \
# 85           Nofoali�i            Fishing           male    M  ...      NaN
# 382   Tyrendarra Beach            Surfing           male    M  ...      NaN
# 4867            Saigon  Wreck of a sampam         8 crew    M  ...      NaN
# 5705               NaN             Diving  a pearl diver    M  ...      NaN
#
#                 Investigator or Source                      pdf  \
# 85           Samoa Observer, 9/16/2017   2017.09.15.a-Samoa.pdf
# ...

# %%
shark_attack_2['Type'].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
shark_attack_2['Type'].str.replace('nan', 'Unknown')
# Out:
# 0          Boating
# 1       Unprovoked
# 2          Invalid
# 3       Unprovoked
# 4         Provoked
#            ...
# 6297    Unprovoked
# 6298    Unprovoked
# 6299    Unprovoked
# 6300    Unprovoked
# 6301    Unprovoked
# Name: Type, Length: 6302, dtype: object

# %%
shark_attack_2["Country"].isnull().sum()
# Out:
# 0

# %%
shark_attack_2['Country'].value_counts()
# Out:
# USA                  2229
# AUSTRALIA            1338
# SOUTH AFRICA          579
# PAPUA NEW GUINEA      134
# NEW ZEALAND           128
#                      ...
# THE BALKANS             1
# ADMIRALTY ISLANDS       1
# Seychelles              1
# GEORGIA                 1
# IRELAND                 1
# Name: Country, Length: 202, dtype: int64

# %%
shark_attack_2['Country'] = shark_attack_2['Country'].str.strip()
characters='!@#$%^&*()[]{};:,./<>?\|`~-=_+'
for i in characters:
    shark_attack_2['Country'] = shark_attack_2['Country'].str.replace(i,'')

# %%
shark_attack_2
# Out:
#      Case Number         Date  Year        Type           Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating               USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked               USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid               USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked         AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked            MEXICO
# ...          ...          ...   ...         ...               ...
# 6297     ND.0005  Before 1903  1903  Unprovoked         AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked         AUSTRALIA
# 6299     ND.0003    1900-1905  1905  Unprovoked               USA
# 6300     ND.0002    1883-1889  1889  Unprovoked            PANAMA
# 6301     ND.0001    1845-1853  1853  Unprovoked  CEYLON SRI LANKA
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# ...

# %%
shark_attack_2['Country'] = shark_attack_2['Country'].fillna('Unknown')

# %%
shark_attack_2
# Out:
#      Case Number         Date  Year        Type           Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating               USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked               USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid               USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked         AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked            MEXICO
# ...          ...          ...   ...         ...               ...
# 6297     ND.0005  Before 1903  1903  Unprovoked         AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked         AUSTRALIA
# 6299     ND.0003    1900-1905  1905  Unprovoked               USA
# 6300     ND.0002    1883-1889  1889  Unprovoked            PANAMA
# 6301     ND.0001    1845-1853  1853  Unprovoked  CEYLON SRI LANKA
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# ...

# %%
shark_attack_2["Area"].isnull().sum()
# Out:
# 455

# %%
shark_attack_2['Area'] = shark_attack_2['Area'].fillna('Unknown')

# %%
shark_attack_2
# Out:
#      Case Number         Date  Year        Type           Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating               USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked               USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid               USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked         AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked            MEXICO
# ...          ...          ...   ...         ...               ...
# 6297     ND.0005  Before 1903  1903  Unprovoked         AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked         AUSTRALIA
# 6299     ND.0003    1900-1905  1905  Unprovoked               USA
# 6300     ND.0002    1883-1889  1889  Unprovoked            PANAMA
# 6301     ND.0001    1845-1853  1853  Unprovoked  CEYLON SRI LANKA
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# ...

# %%
shark_attack_2["Sex "].isnull().sum()
# Out:
# 565

# %%
shark_attack_2['Sex '] = shark_attack_2['Sex '].fillna('Unknown')

# %%
shark_attack_2["Sex "].unique()
# Out:
# array(['F', 'M', 'Unknown', 'M ', 'lli', 'N', '.'], dtype=object)

# %%
shark_attack_2["Sex "].strip
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-a124c4277fff> in <module>
# ----> 1 shark_attack_2["Sex "].strip
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strip'
