# %%
import pandas as pd
import numpy as np

# %%
shark_attacks=pd.read_csv("/Users/nayibahued/Desktop/attacks.csv",sep=',',encoding='latin-1')

# %%
shark_attacks.head(50)

##We start by identifying unnescesary columns
# Out:
#      Case Number                  Date    Year          Type        Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating            USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked            USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid            USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked         MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked         BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked            USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked            USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked            USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked      AUSTRALIA
# ...

# %%
shark_attacks.info()
##Unnamed 1 and 2 has only 3 values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
##We´re gonna drop the rows that have a NaN on the whole columns
shark_attacks=shark_attacks.dropna(how='all')

# %%
shark_attacks.tail(100)
##We notice that in some rows case number is zero, so we´re gonna turn that zero into a NaN
##And the apply the drop rows functions again
shark_attacks['Case Number'] = shark_attacks['Case Number'].replace({'0':np.nan, 0:np.nan,'xx':np.nan})
shark_attacks.tail(100)
shark_attacks=shark_attacks.dropna(how='all')
shark_attacks.tail(100)
# Out:
#      Case Number                 Date  Year        Type       Country  \
# 6209     ND.0110  No date, late 1960s   0.0  Unprovoked     VENEZUELA
# 6210     ND-0109          Before 2006   0.0  Unprovoked           USA
# 6211     ND-0108          Before 2003   0.0  Unprovoked        GREECE
# 6212     ND-0107          Before 2004   0.0        Boat    MOZAMBIQUE
# 6213     ND-0106          Before 1962   0.0  Unprovoked  SOUTH AFRICA
# ...          ...                  ...   ...         ...           ...
# 6304         NaN                  NaN   NaN         NaN           NaN
# 6305         NaN                  NaN   NaN         NaN           NaN
# 6306         NaN                  NaN   NaN         NaN           NaN
# 6307         NaN                  NaN   NaN         NaN           NaN
# 6308         NaN                  NaN   NaN         NaN           NaN
#
#                        Area                        Location  \
# 6209    Los Roques  Islands                             NaN
# ...

# %%
shark_attacks.shape
##We started with 25000 rows or so, now we have cleaned the NaN ones, and got:
# Out:
# (6309, 24)

# %%
shark_attacks.isna().sum()
# Out:
# Case Number                  8
# Date                         7
# Year                         9
# Type                        11
# Country                     57
# Area                       462
# Location                   547
# Activity                   551
# Name                       217
# Sex                        572
# Age                       2838
# Injury                      35
# Fatal (Y/N)                546
# Time                      3361
# Species                   2845
# Investigator or Source      24
# pdf                          7
# href formula                 8
# href                         7
# Case Number.1                7
# Case Number.2                7
# original order               0
# Unnamed: 22               6308
# Unnamed: 23               6307
# dtype: int64

# %%
##We can see there´s two useless columns, so we´re dropping them
shark_attacks.drop(['Unnamed: 22', 'Unnamed: 23'], axis=1, inplace=True)

# %%
##Now that we made a general cleaning of the NaN values, we can start the specific cleaning
shark_attacks.head(10)
##We see a redundance in case number and in href formula too
shark_attacks.drop(['Case Number', 'Case Number.2','href formula'], axis=1, inplace=True)

# %%
shark_attacks.drop_duplicates(keep = 'first', inplace = True)
shark_attacks.reset_index(drop=True, inplace = True)

# %%
shark_attacks.isna().sum()
# Out:
# Date                         7
# Year                         9
# Type                        11
# Country                     57
# Area                       462
# Location                   547
# Activity                   551
# Name                       217
# Sex                        572
# Age                       2838
# Injury                      35
# Fatal (Y/N)                546
# Time                      3361
# Species                   2845
# Investigator or Source      24
# pdf                          7
# href                         7
# Case Number.1                7
# original order               0
# dtype: int64

# %%
##We can see that our most relaiable column is original order, because it has no null data
attacks_sort=shark_attacks.copy()
a_s
# Out:
#              Date  Year        Type             Country               Area  \
# 6308          NaN   NaN         NaN                 NaN                NaN
# 6307          NaN   NaN         NaN                 NaN                NaN
# 6306          NaN   NaN         NaN                 NaN                NaN
# 6305          NaN   NaN         NaN                 NaN                NaN
# 6304          NaN   NaN         NaN                 NaN                NaN
# ...           ...   ...         ...                 ...                ...
# 6297  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905   0.0  Unprovoked                 USA     North Carolina
# 6300    1883-1889   0.0  Unprovoked              PANAMA                NaN
# 6301    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# ...

# %%
##There´s still a lot of empty rows, so we´re gonna set the following condition: drop the row that doesn´t have date,
##country, injury, investigator, and href at the same time

as_new=a_s.dropna(subset=['Date', 'Country', 'Injury', 'Investigator or Source','href'], how='all')
as_new.head(10)
# Out:
#           Date    Year        Type    Country             Area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# 0                        Oceanside, San Diego County      Paddling
# 1                     St. Simon Island, Glynn County      Standing
# 2                                       Habush, Oahu       Surfing
# ...

# %%
##Let´s find how many null cells we have
as_new.isna().sum()
# Out:
# Date                         0
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# pdf                          0
# href                         0
# Case Number.1                0
# original order               0
# dtype: int64

# %%
as_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6302 entries, 0 to 6301
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    6302 non-null   object
#  1   Year                    6300 non-null   float64
#  2   Type                    6298 non-null   object
#  3   Country                 6252 non-null   object
#  4   Area                    5847 non-null   object
#  5   Location                5762 non-null   object
#  6   Activity                5758 non-null   object
#  7   Name                    6092 non-null   object
#  8   Sex                     5737 non-null   object
#  9   Age                     3471 non-null   object
#  10  Injury                  6274 non-null   object
#  11  Fatal (Y/N)             5763 non-null   object
#  12  Time                    2948 non-null   object
#  13  Species                 3464 non-null   object
# ...

# %%
as_new
# Out:
#              Date    Year        Type             Country               Area  \
# 0     25-Jun-2018  2018.0     Boating                 USA         California
# 1     18-Jun-2018  2018.0  Unprovoked                 USA            Georgia
# 2     09-Jun-2018  2018.0     Invalid                 USA             Hawaii
# 3     08-Jun-2018  2018.0  Unprovoked           AUSTRALIA    New South Wales
# 4     04-Jun-2018  2018.0    Provoked              MEXICO             Colima
# ...           ...     ...         ...                 ...                ...
# 6297  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6300    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %%
##Now we`re cleaning column by column
as_1=as_new.copy()
as_1['Year'].unique()
# Out:
# array([2018., 2017.,   nan, 2016., 2015., 2014., 2013., 2012., 2011.,
#        2010., 2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002.,
#        2001., 2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994.,
#        1993., 1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986.,
#        1985., 1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976.,
#        1975., 1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966.,
#        1965., 1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957.,
#        1956., 1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948.,
#        1848., 1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940.,
#        1939., 1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931.,
#        1930., 1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922.,
#        1921., 1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913.,
#        1912., 1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904.,
# ...

# %%
as_1['Year'] = as_1['Year'].fillna(0)

as_1['Year'].unique()
# Out:
# array([2018., 2017.,    0., 2016., 2015., 2014., 2013., 2012., 2011.,
#        2010., 2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002.,
#        2001., 2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994.,
#        1993., 1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986.,
#        1985., 1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976.,
#        1975., 1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966.,
#        1965., 1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957.,
#        1956., 1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948.,
#        1848., 1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940.,
#        1939., 1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931.,
#        1930., 1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922.,
#        1921., 1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913.,
#        1912., 1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904.,
# ...

# %%
##Let´s keep the attacks after 1800
as_2 = as_1.drop(as_1[(as_1['Year'] <1800) & (as_1['Year'] >=5)].index)
as_2['Year'].unique()
# Out:
# array([2018., 2017.,    0., 2016., 2015., 2014., 2013., 2012., 2011.,
#        2010., 2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002.,
#        2001., 2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994.,
#        1993., 1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986.,
#        1985., 1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976.,
#        1975., 1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966.,
#        1965., 1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957.,
#        1956., 1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948.,
#        1848., 1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940.,
#        1939., 1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931.,
#        1930., 1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922.,
#        1921., 1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913.,
#        1912., 1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904.,
# ...

# %%
as_2['Type'].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
##Unifying the type
as_2['Type'] = as_2['Type'].str.replace('nan', 'UNKNOWN')
as_2['Type'] = as_2['Type'].str.replace('Boatinginginginging', 'Boat')
as_2['Type'] = as_2['Type'].str.replace('Boatinginginging', 'Boat')
as_2['Type'] = as_2['Type'].str.replace('Boatomg', 'Boat')

as_2['Type'].unique()
as_3=as_2.copy()

# %%
as_3['Country'].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
# ...

# %%
as_3['Country'] = as_3['Country'].str.replace('ST HELENA, British overseas territory', 'UNITED KINGDOM')
as_3['Country'] = as_3['Country'].str.replace('FRENCH POLYNESIA', 'FRANCE')
as_3['Country'] = as_3['Country'].str.replace('COLUMBIA', 'COLOMBIA')
as_3['Country'] = as_3['Country'].str.replace('Fiji', 'FIJI')
as_3['Country'] = as_3['Country'].str.replace('DIEGO GARCIA', 'UNKNOWN')
as_3['Country'] = as_3['Country'].str.replace('UNITED ARAB EMIRATES (UAE)', 'UAE')
as_3['Country'] = as_3['Country'].str.replace('GULF OF ADEN', 'SOMALIA')
as_3['Country'] = as_3['Country'].str.replace('Sierra Leone', 'SIERRA LEONE')
as_3['Country'] = as_3['Country'].str.replace('Seychelles', 'SEYCHELLES')
as_3['Country'] = as_3['Country'].str.replace('OKINAWA', 'JAPAN')
as_3['Country'] = as_3['Country'].str.replace('BRITISH ISLES', 'UNITED KINGDOM')
as_3['Country'] = as_3['Country'].str.replace('SOUTH CHINA SEA', 'CHINA')
as_3['Country'] = as_3['Country'].str.replace('BRITISH WEST INDIES', 'UNITED KINGDOM')
as_3['Country'] = as_3['Country'].str.replace('SUDAN?', 'SUDAN')
as_3['Country'] = as_3['Country'].str.replace('INDIAN OCEAN', 'INDIA')
as_3['Country'] = as_3['Country'].str.replace('OCEAN', 'UNKNOWN')
as_3['Country'] = as_3['Country'].str.replace('INDIAN OCEAN?', 'INDIA')
as_3['Country'] = as_3['Country'].str.replace('Coast of AFRICA', 'AFRICA')
as_3['Country'] = as_3['Country'].str.replace('RED SEA?', 'RED SEA')
as_3['Country'] = as_3['Country'].str.replace('CEYLON (SRI LANKA)', 'SRI LANKA')
as_3.rename(columns={'Country':'Country/Region'}, inplace=True)

# %%
as_4=as_3.copy()
as_4['Area'].unique()
# Out:
# array(['California', 'Georgia', 'Hawaii', 'New South Wales', 'Colima',
#        'Pernambuco', 'Florida', 'Queensland', 'South Carolina',
#        'Cornwall', 'Westerm Australia', 'Eastern Cape Province',
#        'Hua Hin', 'Cocos Island', 'Western Australia',
#        'Alifu Alifu Atoll', 'Western Cape Province', 'New Providence',
#        'Alagoas', nan, 'Victoria', 'KwaZulu-Natal',
#        'Boi Island, Victoria', 'Galapagos Islands', 'Fernando de Noronha',
#        'Sepang', 'Holquin Province', 'Pamplemousses ', 'South Australia',
#        'North Island', 'New York', 'Canary Islands', ' Upolu Island',
#        'Shizuoka Prefecture', 'Texas', 'Castellón', 'Massachusetts',
#        'Red Sea Protectorate', 'New Providence District',
#        '40 miles off Grand Bahama Island', 'Ascension Island',
#        'New Jersey', 'Majorca', 'Washington', 'Tabasco', 'Anjouan',
#        'Ibiza Island', 'Marquesas', 'South Devon', 'New Providence ',
# ...

# %%
as_4['Area'] = as_4['Area'].fillna('Unknown')
as_4['Area'] = as_4['Area'].str.strip()
as_4['Area'] = as_4['Area'].str.replace('740 miles SE of ','')
as_4['Area'] = as_4['Area'].str.replace('  Primorsky Krai (Far East)','Primorsky Krai (Far East)')
as_4['Area'] = as_4['Area'].str.replace('300 miles from Antigua','Antigua')
as_4['Area'] = as_4['Area'].str.replace('10ºS, 142ºE','Unknown')
as_4['Area'] = as_4['Area'].str.replace('04.05N-13.23W','Unknown')
as_4['Area'] = as_4['Area'].str.replace('22ºN, 88ºE','Unknown')
as_4['Area'] = as_4['Area'].str.replace("35º39 : 165º8'",'Unknown')
as_4['Area'] = as_4['Area'].str.replace('"','')
as_4['Area'] = as_4['Area'].str.replace('?','')
as_4['Area'] = as_4['Area'].str.replace('(','')
as_4['Area'] = as_4['Area'].str.replace(')','')

# %%
as_5=as_4.copy()
as_5['Sex '].unique()
as_5['Sex '] = as_5['Sex '].fillna('Unknown')
as_5['Sex '] = as_5['Sex '].str.replace('M ','M')
as_5['Sex '] = as_5['Sex '].str.replace('N','M')
as_5['Sex '] = as_5['Sex '].str.replace('lli','Unknown')
as_5['Sex '] = as_5['Sex '].str.replace('.','Unknown')
as_6=as_5.copy()

# %%
as_6=as_5.copy()
as_6['Age'].unique()
as_6['Age'] = as_6['Age'].fillna('Unknown')
as_6['Age'] = as_6['Age'].str.replace('40s','40')
as_6['Age'] = as_6['Age'].str.replace('20s','20')
as_6['Age'] = as_6['Age'].str.replace('60s','60')
as_6['Age'] = as_6['Age'].str.replace('18 months','1')
as_6['Age'] = as_6['Age'].str.replace('30s','30')
as_6['Age'] = as_6['Age'].str.replace('50s','50')
as_6['Age'] = as_6['Age'].str.replace('teen','Unknown')
as_6['Age'] = as_6['Age'].str.replace('Teen','Unknown')
as_6['Age'] = as_6['Age'].str.replace('18 or 20','19')
as_6['Age'] = as_6['Age'].str.replace('12 or 13','12')
as_6['Age'] = as_6['Age'].str.replace('Teens','Unknown')
as_6['Age'] = as_6['Age'].str.replace('8 or 10','9')
as_6['Age'] = as_6['Age'].str.replace('','Unknown')
as_6['Age'] = as_6['Age'].str.replace('30 or 36','Unknown')
as_6['Age'] = as_6['Age'].str.replace('6½','6')
as_6['Age'] = as_6['Age'].str.replace('21 & ','21')
as_6['Age'] = as_6['Age'].str.replace('33 or 37','Unknown')
as_6['Age'] = as_6['Age'].str.replace('7      &    31','7 & 31')
as_6['Age'] = as_6['Age'].str.replace('20?','20')
as_6['Age'] = as_6['Age'].str.replace("60's",'60')
as_6['Age'] = as_6['Age'].str.replace('Ca. 33','33')
as_6['Age'] = as_6['Age'].str.replace('MAKE LINE GREEN','Unknown')
as_6['Age'] = as_6['Age'].str.replace('Ca. 33','33')
as_6['Age'] = as_6['Age'].str.replace('A.M.','Unknown')

# %%
as_7=as_6.copy()
as_7['Fatal (Y/N)'].unique()
as_7['Fatal (Y/N)'] = as_7['Fatal (Y/N)'].fillna('Unknown')
as_7['Fatal (Y/N)'] = as_7['Fatal (Y/N)'].str.replace('M','N')
as_7['Fatal (Y/N)'] = as_7['Fatal (Y/N)'].str.replace('2017','Unknown')
as_7['Fatal (Y/N)'] = as_7['Fatal (Y/N)'].str.replace('UNKNOWN','Unknown')
as_7['Fatal (Y/N)'] = as_7['Fatal (Y/N)'].str.replace(' N','N')
as_7['Fatal (Y/N)'] = as_7['Fatal (Y/N)'].str.replace('N ','N')
as_7['Fatal (Y/N)'] = as_7['Fatal (Y/N)'].str.replace('y','Y')
as_7['Age']=as_7['Age'].str.replace('Unknown',' ')

# %%
as_7['Time'] = as_7['Time'].fillna(' ')
as_7['Species '] = as_7['Species '].fillna(' ')
as_7['Name'] = as_7['Name'].str.replace('male',' ')
as_7
# Out:
#              Date    Year        Type      Country/Region               Area  \
# 0     25-Jun-2018  2018.0        Boat                 USA         California
# 1     18-Jun-2018  2018.0  Unprovoked                 USA            Georgia
# 2     09-Jun-2018  2018.0     Invalid                 USA             Hawaii
# 3     08-Jun-2018  2018.0  Unprovoked           AUSTRALIA    Mew South Wales
# 4     04-Jun-2018  2018.0    Provoked              MEXICO             Colima
# ...           ...     ...         ...                 ...                ...
# 6297  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905     0.0  Unprovoked                 USA     Morth Carolina
# 6300    1883-1889     0.0  Unprovoked              PANAMA            Unknown
# 6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %%
##Let´s check the NaN values
as_7.isna().sum()
# Out:
# Date                        0
# Year                        0
# Type                        4
# Country/Region             44
# Area                        0
# Location                  524
# Activity                  531
# Name                      207
# Sex                         0
# Age                         0
# Injury                     21
# Fatal (Y/N)                 0
# Time                        0
# Species                     0
# Investigator or Source     16
# pdf                         0
# href                        0
# Case Number.1               0
# original order              0
# dtype: int64

# %%
as_7['Type'] = as_7['Type'].fillna('Unknown')
as_7['Country/Region'] = as_7['Country/Region'].fillna('Unknown')
as_7['Location'] = as_7['Location'].fillna('Unknown')
as_7['Activity'] = as_7['Activity'].fillna('Unknown')
as_7['Name'] = as_7['Name'].fillna('Unknown')
as_7['Injury'] = as_7['Injury'].fillna('Unknown')
as_7['Investigator or Source'] = as_7['Investigator or Source'].fillna('Unknown')

# %%
as_7.isna().sum()
# Out:
# Date                      0
# Year                      0
# Type                      0
# Country/Region            0
# Area                      0
# Location                  0
# Activity                  0
# Name                      0
# Sex                       0
# Age                       0
# Injury                    0
# Fatal (Y/N)               0
# Time                      0
# Species                   0
# Investigator or Source    0
# pdf                       0
# href                      0
# Case Number.1             0
# original order            0
# dtype: int64

# %%
as_7.to_csv('/Users/nayibahued/Desktop/datamex_082020/module-1/pandas-project/your-code/shark_attacks.csv', index = False, sep =',')

# %% [markdown]
# # DATA ANALYSIS

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
as_7_=as_7.copy()
as_7_['YEARgraph'] = as_7[as_7['Year']>1800]['Year']
year_counter = as_7_['YEARgraph'].value_counts().sort_index()

year_counter.plot(title='Shark Attacks Per Year 1800 - 2018',color = 'green')
print("This graph represents the shark atttacks per year all over the world from 1800 to 2018")
# Out:
# This graph represents the shark atttacks per year all over the world from 1800 to 2018

# %%
as_7['Sex '].value_counts().plot(kind = 'pie')
print("The relation of the attacked genre")
# Out:
# The relation of the attacked genre

# %%
as_7['Type'].value_counts().plot(kind = 'pie')
print("Here we can see, what was the origin of the attack")
# Out:
# Here we can see, what was the origin of the attack

# %%
as_7['Fatal (Y/N)'].value_counts().plot(kind = 'pie')
print("With this chart we know if the attack was fatal or not")
# Out:
# With this chart we know if the attack was fatal or not

# %%
as_8=as_7.copy()
cntr=as_8['Country/Region'].value_counts()[0:7]
print("These are the top 6 countries where there has been shark attacks")
cntr
# Out:
# These are the top 6 countries where there has been shark attacks
# USA                 2224
# AUSTRALIA           1335
# SOUTH AFRICA         579
# PAPUA NEW GUINEA     134
# NEW ZEALAND          128
# BRAZIL               112
# BAHAMAS              109
# Name: Country/Region, dtype: int64
