# %%
import pandas as pd
import numpy as np

# %%
data_attacks = pd.read_csv('attacks.csv', engine = 'python', sep=',' )

# %%
data_attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
data_atta=data_attacks.copy()

# %%
data_atta.shape
# Out:
# (25723, 24)

# %%
data_atta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
# We saw that there is a mode in the non-null, and we won't conteplate the columns that have more nulls than the mode
tittles=data_atta.columns.values 
tittles=np.delete(tittles,(0,21))
tittles
# Out:
# array(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'Unnamed: 22', 'Unnamed: 23'],
#       dtype=object)

# %%
# We will eliminate the duplicates rows
data_atta.drop_duplicates(tittles,keep = 'first', inplace=True)

# %%
data_atta.shape
# Out:
# (6303, 24)

# %%
data_atta.tail(5)
# Out:
#      Case Number         Date  Year        Type             Country  \
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
# 6302           0          NaN   NaN         NaN                 NaN
#
#                    Area                             Location      Activity  \
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
# 6302                NaN                                  NaN           NaN
#
#                        Name Sex   ... Species   \
# 6298                  Ahmun    M  ...      NaN
# ...

# %%
# We will eliminate the las row because it doesn't have values
data_atta.drop(len(data_atta)-1,axis=0, inplace=True)

# %%
data_atta.tail(5)
# Out:
#      Case Number         Date  Year        Type             Country  \
# 6297     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ... Species   \
# 6297                   male    M  ...      NaN
# ...

# %%
data_atta.isnull().sum()
# Out:
# Case Number                  1
# Date                         0
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6301
# Unnamed: 23               6300
# dtype: int64

# %%
data_un22=data_atta['Unnamed: 22']
data_un22.sort_values()
# So we have 1 and 2 data in Unnamed: 22 and Unnamed: 23
# Out:
# 1478    stopped here
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
#             ...
# 6297             NaN
# 6298             NaN
# 6299             NaN
# 6300             NaN
# 6301             NaN
# Name: Unnamed: 22, Length: 6302, dtype: object

# %%
#data_atta.drop(labels=['Unnamed: 22','Unnamed: 23'],axis=1, inplace=True)

# %%
data_atta.tail(5)
# Out:
#      Case Number         Date  Year        Type             Country  \
# 6297     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ... Species   \
# 6297                   male    M  ...      NaN
# ...

# %%
files=[]
datita = data_atta.where(data_atta['Case Number']==data_atta['Case Number.1'],axis=0)

# %%
data_atta[data_atta['Case Number']!=data_atta['Case Number.1']].head()
#datita['Case Number'].isnull().sum()
# Out:
#       Case Number         Date    Year        Type       Country  \
# 34     2018.04.03  03-Apr-2018  2018.0  Unprovoked  SOUTH AFRICA
# 117  2017.07.20.a  20-Jul-2017  2017.0  Unprovoked           USA
# 144    2017.05.06  05-May-2017  2017.0  Unprovoked        MEXICO
# 217    2016.09.15  16-Sep-2016  2016.0  Unprovoked     AUSTRALIA
# 314  2016.01.24.b  24-Jan-2016  2016.0  Unprovoked           USA
#
#                       Area                                Location  \
# 34   Eastern Cape Province                         St. Francis Bay
# 117             California  Seal Rock, Goleta Beach, Santa Barbara
# 144    Baja California Sur               Los Arbolitos, Cabo Pulmo
# 217               Victoria                             Bells Beach
# 314                  Texas                            Off Surfside
#
#          Activity           Name Sex   ...                Species   \
# 34        Surfing   Ross Spowart    M  ...             White shark
# ...

# %%
data_atta.head(15)
# Out:
#      Case Number         Date    Year        Type    Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# 5   2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 6   2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL
# 7     2018.05.27  27-May-2018  2018.0  Unprovoked        USA
# 8   2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA
# 9   2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA
# 10    2018.05.24  24-May-2018  2018.0    Provoked  AUSTRALIA
# 11    2018.05.21  21-May-2018  2018.0  Unprovoked        USA
# 12  2018.05.13.b  13-May-2018  2018.0  Unprovoked        USA
# 13  2018.05.13.a  13-May-2018  2018.0     Invalid    ENGLAND
# ...

# %%
data_atta['Year'].dtype
# Out:
# dtype('float64')

# %%
data_atta['Year'].isnull().sum()
# Out:
# 2

# %%
data_atta[data_atta['Year'].isnull()]
# Out:
#        Case Number                  Date  Year        Type    Country  \
# 187   2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA
# 6079  1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex   ...  \
# 187   Queensland         NaN  Spearfishing  Kerry Daniel    M  ...
# 6079  Cumberland  Whitehaven      Swimming         a boy    M  ...
#
#         Species   Investigator or Source                           pdf  \
# 187   Bull shark  Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf
# 6079         NaN          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                            href formula  \
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6079  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.01.08.R
# ...

# %%
#for i in data_atta['Year'][data_atta['Year'].isnull()]:
    
gol=data_atta['Year'][data_atta['Year'].isnull()].index
for i in gol:
    gol_2=data_atta['Date'][i]
    data_atta['Year'][i]=float(gol_2[-4:])

# %%
data_atta['Year'][187]
# Out:
# 2017.0

# %%
gol=data_atta['Year'][data_atta['Year']==0].index
for i in gol:
    gol_2=data_atta['Date'][i]
    try:
        data_atta['Year'][i]=float(gol_2[-4:])
    except:
        data_atta['Year'][i]='Revisar año'

# %%
data_atta[data_atta['Year']=='Revisar año']
# Out:
#      Case Number                 Date         Year          Type  \
# 6177   0000.0214         Ca. 214 B.C.  Revisar año    Unprovoked
# 6178   0000.0336        Ca. 336.B.C..  Revisar año    Unprovoked
# 6179   0000.0493             493 B.C.  Revisar año  Sea Disaster
# 6180   0000.0725         Ca. 725 B.C.  Revisar año  Sea Disaster
# 6187     ND-0148                2009?  Revisar año    Unprovoked
# 6209     ND.0110  No date, late 1960s  Revisar año    Unprovoked
# 6214     ND.0104                1950s  Revisar año    Unprovoked
# 6216     ND.0100                2003?  Revisar año    Unprovoked
# 6217     ND.0097              No date  Revisar año    Unprovoked
# 6218     ND.0096              No date  Revisar año    Unprovoked
# 6241     ND.0065                1960s  Revisar año    Unprovoked
# 6242     ND.0064                1960s  Revisar año    Unprovoked
# 6243     ND.0063                1960s  Revisar año    Unprovoked
# ...

# %%
data_atta['Type'].value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
# We don´t modificate the column 'Type', because we consider that each type of attack is different

# %%
data_atta['Country'].value_counts()
# Out:
# USA                          2229
# AUSTRALIA                    1338
# SOUTH AFRICA                  579
# PAPUA NEW GUINEA              134
# NEW ZEALAND                   128
#                              ...
# SYRIA                           1
# NORTH SEA                       1
# REUNION ISLAND                  1
# NORTH ATLANTIC OCEAN            1
# SOLOMON ISLANDS / VANUATU       1
# Name: Country, Length: 212, dtype: int64

# %%
data_atta['Country'].dtype
# Out:
# dtype('O')

# %%
data_atta['Country']=data_atta['Country'].str.strip()
characters='!@#$%^&*()[]{};:,./<>?\|`~-=_+'
for i in characters:
    data_atta['Country']=data_atta['Country'].str.replace(i,'')

# %%
data_atta['Country']=data_atta['Country'].fillna('país desconocido')

# %%
data_atta['Country'].value_counts()
# Out:
# USA                 2229
# AUSTRALIA           1338
# SOUTH AFRICA         579
# PAPUA NEW GUINEA     134
# NEW ZEALAND          128
#                     ...
# Seychelles             1
# SLOVENIA               1
# CEYLON SRI LANKA       1
# FALKLAND ISLANDS       1
# BAY OF BENGAL          1
# Name: Country, Length: 202, dtype: int64

# %%
data_atta['Area'].isnull().sum()
# Out:
# 455

# %%
data_atta['Area']=data_atta['Area'].fillna('Área no especificada')

# %%
data_atta['Area'].value_counts()
# Out:
# Florida                  1037
# New South Wales           486
# Área no especificada      455
# Queensland                311
# Hawaii                    298
#                          ...
# Sofala Province             1
# Cortés                      1
# Panama City                 1
# Santa Isabel Province       1
# L'Etang-Sale                1
# Name: Area, Length: 826, dtype: int64

# %%
data_atta.head()
# Out:
#   Case Number         Date  Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# ...

# %%
data_atta['Location'].isnull().sum()
# Out:
# 540

# %%
data_atta[data_atta['Location'].isnull()].head()
# Out:
#       Case Number                  Date  Year        Type           Country  \
# 56     2017.12.09           09-Dec-2017  2017  Unprovoked           BAHAMAS
# 62   2017.11.13.R  Reported 13-Nov-2017  2017  Unprovoked  país desconocido
# 101    2017.08.18           18-Aug-2017  2017  Unprovoked           BAHAMAS
# 110  2017.07.26.R  Reported 26-Jul-2017  2017  Unprovoked           BAHAMAS
# 132  2017.06.14.R  Reported 14-Jun-2017  2017  Unprovoked           BAHAMAS
#
#                                  Area Location        Activity  \
# 56               Área no especificada      NaN      Snorkeling
# 62               Área no especificada      NaN         Surfing
# 101              Área no especificada      NaN    Spearfishing
# 110  40 miles off Grand Bahama Island      NaN    Spearfishing
# 132              Área no especificada      NaN  Feeding sharks
#
#                     Name Sex   ...         Species   \
# 56   Sarah Illig-Carroll    F  ...  Nurse shark. 5'
# ...

# %%
data_atta['Location']=data_atta['Location'].fillna('Localidad desconocida')

# %%
act_pri=data_atta['Activity'].value_counts(20)

# %%
import re

# %%
act_pri_2=[act_pri.keys()]
for i in act_pri_2:
    for j in data_atta['Activity']:
        try:
            re.sub(i,data_atta['Activity'][j],i)
        except:
            act_pri_2.append(data_atta['Activity'][j])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-203-b191c306664f> in <module>
#       4         try:
# ----> 5             re.sub(i,data_atta['Activity'][j],i)
#       6         except:
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
act_es=['Surfing','Swimming',
'Fishing',
'Spearfishing',
'Bathing',
'Wading','Diving','Standing','Snorkeling','Scuba diving','Body boarding','Body surfing','Swimming','Kayaking',
'Treading water',
'Fell overboard',
'Pearl diving',
'Free diving','Boogie boarding',
'Windsurfing']

# %%
for i in act_es:
    for j in datita['Activity']:
        if i in datita['Activity'][j]:
            datita['Activity'][j]=i
        else:
            pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-e18389397905> in <module>
#       1 for i in act_es:
#       2     for j in datita['Activity']:
# ----> 3         if i in datita['Activity'][j]:
#       4             datita['Activity'][j]=i
#       5         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
# ...

# %%
type(act)
# Out:
# list

# %%
print(act)
# Out:
# [Surfing                                                                                                              971
# Swimming                                                                                                             869
# Fishing                                                                                                              431
# Spearfishing                                                                                                         333
# Bathing                                                                                                              162
#                                                                                                                     ...
# A 75-ton  Japanese fishing ship was sunk by  Chinese Nationalist gunboat, shipwrecked men were clinging to debris      1
# Touching the mouth of a supposedly dead shark                                                                          1
# ...
