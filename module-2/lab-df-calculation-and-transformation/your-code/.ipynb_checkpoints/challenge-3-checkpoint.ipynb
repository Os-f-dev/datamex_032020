# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders.csv` data set in the previous [Subsetting and Descriptive Stats lab](../../lab-subsetting-and-descriptive-stats/your-code/main.ipynb). In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# # Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders.csv` from the "subsetting" lab folder into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# enter your code here
orders = pd.read_csv("../../lab-subsetting-and-descriptive-stats/your-code/Orders.zip")
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# your code here
new_cust = orders.groupby('CustomerID').sum()
new_cust.head()
# Out:
#             Unnamed: 0  InvoiceNo    year  month  day  hour  Quantity  \
# CustomerID
# 12346            61619     541431    2011      1    2    10     74215
# 12347         42441700  101296926  365971   1383  441  2219      2458
# 12348          2807120   16869685   62324    257  111   472      2341
# 12349         35444274   42165457  146803    803   73   657       631
# 12350          1365627    9231629   34187     34   51   272       197
#
#             UnitPrice  amount_spent
# CustomerID
# 12346            1.04      77183.60
# 12347          481.21       4310.00
# 12348          178.71       1797.24
# 12349          605.10       1757.55
# 12350           65.30        334.40

# %%
new_cust[new_cust['amount_spent']>new_cust['amount_spent'].quantile(.95)]
# Out:
#             Unnamed: 0  InvoiceNo     year  month   day  hour  Quantity  \
# CustomerID
# 12346            61619     541431     2011      1     2    10     74215
# 12357         58262250   75290940   263441   1441   917  2096      2708
# 12359         59103884  138190725   498728   1508   783  3136      1622
# 12409         30112571   61157926   219199    789   499  1222      5551
# 12415        164201777  398543981  1439876   4254  2169  8061     77670
# ...                ...        ...      ...    ...   ...   ...       ...
# 18109        116807851  248314878   892863   3110  2156  6080      4237
# 18139         77545172   91867873   319749   1749   209  2090      5557
# 18172         45497499  105352467   380079   1128   679  2506      3184
# 18223         66402225  151665538   546971   1843   781  3290      2948
# 18229         44387325   91863926   329794   1223   631  1921      2488
#
#             UnitPrice  amount_spent
# CustomerID
# 12346            1.04      77183.60
# ...

# %%
new_cust[(new_cust['amount_spent']<new_cust['amount_spent'].quantile(.95)) & (new_cust['amount_spent']>new_cust['amount_spent'].quantile(.75))]
# Out:
#             Unnamed: 0  InvoiceNo     year  month   day   hour  Quantity  \
# CustomerID
# 12347         42441700  101296926   365971   1383   441   2219      2458
# 12348          2807120   16869685    62324    257   111    472      2341
# 12349         35444274   42165457   146803    803    73    657       631
# 12352         22083029   47523155   170935    552   243   1193       536
# 12356          6327889   32183405   118649    142   185    592      1591
# ...                ...        ...      ...    ...   ...    ...       ...
# 18259         13890450   23741242    84455    427   133    553       714
# 18260         18050916   73457520   269463    577   436   1616      1478
# 18272         49405922   93342091   333826   1221   509   2107      2050
# 18283        233950830  425704048  1520316   5503  2489  10346      1397
# 18287         21958901   39474556   140770    555   332    697      1586
#
#             UnitPrice  amount_spent
# CustomerID
# ...

# %%
new_cust['Type of customer']=np.where(new_cust['amount_spent']>new_cust['amount_spent'].quantile(.95),'VIP',
                                        np.where(new_cust['amount_spent']>new_cust['amount_spent'].quantile(.75),'Preferred','nan'))

# %%
new_cust
# Out:
#             Unnamed: 0  InvoiceNo     year  month   day   hour  Quantity  \
# CustomerID
# 12346            61619     541431     2011      1     2     10     74215
# 12347         42441700  101296926   365971   1383   441   2219      2458
# 12348          2807120   16869685    62324    257   111    472      2341
# 12349         35444274   42165457   146803    803    73    657       631
# 12350          1365627    9231629    34187     34    51    272       197
# ...                ...        ...      ...    ...   ...    ...       ...
# 18280          1110495    5457120    20110     30    10     90        45
# 18281          1560699    3895248    14077     42    49     70        54
# 18282          4642134    6838540    24132    116    60    146       103
# 18283        233950830  425704048  1520316   5503  2489  10346      1397
# 18287         21958901   39474556   140770    555   332    697      1586
#
#             UnitPrice  amount_spent Type of customer
# CustomerID
# ...

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# # Q2: How to identify which country has the most VIP Customers?
#
# # Q3: How to identify which country has the most VIP+Preferred Customers combined?
#
# Provide your solution for Q2 below:

# %%
# your code here
def label(y):
    if y>new_cust['amount_spent'].quantile(.95):
        return 'VIP'
    elif y>new_cust['amount_spent'].quantile(.75):
        return 'Preferred'
    else:
        return 'simple'
    
orders['Type customer']=new_cust['amount_spent'].apply(label)

# %%
orders[orders['Type customer']=='VIP'].head()
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 12346       19174     537843     22776  2010     12    3    15
# 12357       19185     537844     22471  2010     12    3    15
# 12359       19187     537844     21287  2010     12    3    15
# 12409       19237     537850     22355  2010     12    3    15
# 12415       19243     537850    62096A  2010     12    3    15
#
#                          Description  Quantity          InvoiceDate  \
# 12346    sweetheart cakestand 3 tier         2  2010-12-08 15:16:00
# 12357    tv dinner tray air hostess          1  2010-12-08 15:17:00
# 12359  scented velvet lounge candle         12  2010-12-08 15:17:00
# 12409      charlotte bag suki design        10  2010-12-08 15:38:00
# 12415    pink/yellow flowers handbag         6  2010-12-08 15:38:00
#
#        UnitPrice  CustomerID         Country  amount_spent Type customer
# 12346       9.95       15713  United Kingdom         19.90           VIP
# ...

# %%
l=orders[['Country','Type customer']][orders['Type customer']=='VIP']
maximo=l.groupby('Country').count().max()
l3=l.groupby('Country').count()
l3=l3.sort_values('Type customer',ascending=False)
l3.index[0]
# Out:
# 'United Kingdom'

# %%
l=orders[['Country','Type customer']][(orders['Type customer']=='VIP') | (orders['Type customer']=='Preferred')]
maximo=l.groupby('Country').count().max()
l3=l.groupby('Country').count()
l3=l3.sort_values('Type customer',ascending=False)
l3.index[0]
# Out:
# 'United Kingdom'

# %%
l3
# Out:
#                  Type customer
# Country
# United Kingdom             971
# Norway                      24
# Germany                     22
# France                      19
# Spain                       15
# EIRE                        12
# Denmark                      8
# Japan                        6
# Portugal                     6
# Channel Islands              2
