# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data1= data.groupby('ItemType')['RetailSales','RetailTransfers','WarehouseSales'].agg('sum')
data1
# Out:
#               RetailSales  RetailTransfers  WarehouseSales
# ItemType
# BEER            209763.11        234924.44      2437617.32
# DUNNAGE              0.00             0.00       -45331.00
# KEGS                 0.00             0.00        43558.00
# LIQUOR          309847.85        334176.41        33173.32
# NON-ALCOHOL       8109.97          9058.37         8656.72
# REF                281.34           171.92        -6754.00
# STR_SUPPLIES       995.98          3594.70            0.00
# WINE            313400.42        340710.51       433009.47

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
bar=('rbg')
data1.plot.bar(figsize=(12,3),rot=10,color=bar)
plt.show();

# %%
data2_1['total_sales'].plot(kind = 'barh', title='Top10 Suppliers')

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data3=data.copy()
data3['Month'] = data3['Month'].astype(str)
data3['Year'] = data3['Year'].astype(str)

# %%
data3['Year-Month']=data3['Year']+'-'+data3['Month']
data3 = data3.groupby('Year-Month')[['RetailSales','RetailTransfers','WarehouseSales']].agg('mean')
data3 = data3.sort_values('Year-Month',ascending=True)
data3
# Out:
#             RetailSales  RetailTransfers  WarehouseSales
# Year-Month
# 2017-10        6.549021         6.827827       22.289367
# 2017-11        6.765496         7.103699       23.348862
# 2017-12        9.078241         8.353759       21.169463
# 2017-4         0.000000        15.707503        0.000000
# 2017-5         7.038838         7.421817       27.310548
# 2017-6         7.143914         6.950396       27.839069
# 2017-8         6.409991         6.584726       28.122641
# 2017-9         6.757254         6.419721       22.817909
# 2018-1         5.679413         5.574833       19.072137
# 2018-2         5.939247         6.050136       20.229658

# %%
data_3 = data.groupby(['Year','Month'])[['RetailSales','RetailTransfers','WarehouseSales']].agg('mean')

data_3.plot.line(figsize=(10,5))
plt.show();

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data4=('byg')
data3.plot.bar(figsize=(15,5),rot=10,grid=True,color=data4)
plt.show();

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data5=pd.pivot_table(data, index = ['Year','Month'],columns='ItemType', values = ['RetailSales'], aggfunc = sum)

data5.fillna(value=0)
# Out:
#            RetailSales                                                         \
# ItemType          BEER DUNNAGE KEGS    LIQUOR NON-ALCOHOL    REF STR_SUPPLIES
# Year Month
# 2017 4            0.00     0.0  0.0      0.00        0.00   0.00         0.00
#      5        25023.24     0.0  0.0  35123.36        0.00   0.00         0.00
#      6        27863.26     0.0  0.0  35035.31     1209.23  30.60        89.22
#      8        23030.13     0.0  0.0  32186.04     1091.28  19.54        77.34
#      9        23852.76     0.0  0.0  32532.32      997.11  38.88        94.64
#      10       22583.78     0.0  0.0  32491.59      945.63  22.82        84.38
#      11       23341.14     0.0  0.0  35524.77     1005.19  63.11       106.06
#      12       28822.16     0.0  0.0  49522.28     1316.44  41.21       439.64
# 2018 1        16606.33     0.0  0.0  28579.87      732.25  23.66        56.94
#      2        18640.31     0.0  0.0  28852.31      812.84  41.52        47.76
#
#
# ...

# %%
data5.plot.line(figsize=(15,10))
leg = plt.legend()
leg_lines = leg.get_lines()
leg_texts = leg.get_texts()
plt.setp(leg_lines, linewidth=6)
plt.setp(leg_texts, fontsize='x-large')
plt.savefig('leg_example')

plt.show();

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
data5.plot.barh(figsize=(25,20),width=.7)
leg = plt.legend()
leg_lines = leg.get_lines()
leg_texts = leg.get_texts()
plt.setp(leg_texts, fontsize='xx-large')
plt.savefig('leg_example')

plt.show();

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
fig = plt.subplots(figsize=(15,20))
sns.scatterplot('RetailSales','RetailTransfers',hue='ItemType',data=data)
plt.show();

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.pairplot(hue='ItemType', kind='scatter', data=data)
plt.show();
