# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128355 entries, 0 to 128354
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             128355 non-null  int64
#  1   Month            128355 non-null  int64
#  2   Supplier         128331 non-null  object
#  3   ItemCode         128355 non-null  object
#  4   Description      128355 non-null  object
#  5   ItemType         128354 non-null  object
#  6   RetailSales      128355 non-null  float64
#  7   RetailTransfers  128355 non-null  float64
#  8   WarehouseSales   128355 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
bar_chart= data.groupby('ItemType')['RetailSales','RetailTransfers','WarehouseSales'].agg(['sum'])
bar_chart
# Out:
#              RetailSales RetailTransfers WarehouseSales
#                      sum             sum            sum
# ItemType
# BEER           209763.11       234924.44     2437617.32
# DUNNAGE             0.00            0.00      -45331.00
# KEGS                0.00            0.00       43558.00
# LIQUOR         309847.85       334176.41       33173.32
# NON-ALCOHOL      8109.97         9058.37        8656.72
# REF               281.34          171.92       -6754.00
# STR_SUPPLIES      995.98         3594.70           0.00
# WINE           313400.42       340710.51      433009.47

# %%
bar_chart.plot(kind = 'bar')

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data['total_sales']=data['RetailSales']+data['WarehouseSales']

# %%
top10_suppliers = data.pivot_table(data, index=['Supplier'])
top10_suppliers
# Out:
#                                 Month  RetailSales  RetailTransfers  \
# Supplier
# 8 VINI INC                   8.000000     0.308889         0.222222
# A HARDY USA LTD              8.666667     0.133333         0.000000
# A I G WINE & SPIRITS         7.575000     0.313000         0.148000
# A VINTNERS SELECTIONS        7.186439     0.991346         0.959282
# A&E INC                      7.815789     0.303158         0.052632
# ...                               ...          ...              ...
# WINEBOW INC                 10.000000     0.177143        -0.225714
# YOUNG WON TRADING INC        7.147477     1.369534         1.354981
# YUENGLING BREWERY            7.011976    57.654790        64.977066
# Z WINE GALLERY IMPORTS LLC   6.966667     0.294333         0.375000
# ZURENA LLC                   7.000000     1.794444         2.296667
#
#                             WarehouseSales         Year  total_sales
# Supplier
# ...

# %%
datasuppliers= top10_suppliers.sort_values('total_sales',ascending=False ).head(10)
datasuppliers
# Out:
#                              Month  RetailSales  RetailTransfers  \
# Supplier
# CROWN IMPORTS             6.947891    66.272531        73.354020
# HEINEKEN USA              7.006160    42.963388        47.236653
# MILLER BREWING COMPANY    6.961240    27.149326        30.369512
# YUENGLING BREWERY         7.011976    57.654790        64.977066
# FIFTH GENERATION INC      6.800000   259.871000       283.167400
# ANHEUSER BUSCH INC        7.078861    19.859608        22.082427
# SINGHA NORTH AMERICA INC  6.800000    36.737000        42.000000
# PABST BREWING CO          7.039773    12.301420        13.829545
# FLYING DOG BREWERY LLLP   7.157761    26.211399        30.185445
# BOSTON BEER CORPORATION   7.019011    20.481464        22.566464
#
#                           WarehouseSales         Year  total_sales
# Supplier
# CROWN IMPORTS                1438.770968  2017.223325  1505.043499
# HEINEKEN USA                  654.645975  2017.209446   697.609363
# ...

# %%
datasuppliers['total_sales'].plot(kind = 'barh', title='top 10 suppliers')

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
datachart = data.pivot_table(data, index=['Year','Month'])
datachart
# Out:
#             RetailSales  RetailTransfers  WarehouseSales  total_sales
# Year Month
# 2017 4         0.000000        15.707503        0.000000     0.000000
#      5         7.038838         7.421817       27.310548    34.349386
#      6         7.143914         6.950396       27.839069    34.982983
#      8         6.409991         6.584726       28.122641    34.532632
#      9         6.757254         6.419721       22.817909    29.575163
#      10        6.549021         6.827827       22.289367    28.838388
#      11        6.765496         7.103699       23.348862    30.114358
#      12        9.078241         8.353759       21.169463    30.247704
# 2018 1         5.679413         5.574833       19.072137    24.751550
#      2         5.939247         6.050136       20.229658    26.168905

# %%
datachart[['RetailSales','RetailTransfers','WarehouseSales']].plot(kind = 'line', title='sales throuh time')

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
datachart[['RetailSales','RetailTransfers','WarehouseSales']].plot(kind = 'bar', title='sales throuh time')

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
datart= data.groupby(['Year','Month','ItemType'])['RetailSales'].agg(['sum'])
datart
# Out:
#                               sum
# Year Month ItemType
# 2017 4     BEER              0.00
#            LIQUOR            0.00
#            NON-ALCOHOL       0.00
#            REF               0.00
#            STR_SUPPLIES      0.00
# ...                           ...
# 2018 2     LIQUOR        28852.31
#            NON-ALCOHOL     812.84
#            REF              41.52
#            STR_SUPPLIES     47.76
#            WINE          29409.39
#
# [73 rows x 1 columns]

# %%
dataretail = data.pivot_table(data, index=['Year','Month'], columns = 'ItemType')
dataretail
# Out:
#            RetailSales                                                \
# ItemType          BEER DUNNAGE KEGS     LIQUOR NON-ALCOHOL       REF
# Year Month
# 2017 4        0.000000     NaN  NaN   0.000000    0.000000  0.000000
#      5       14.455945     NaN  NaN  12.136614         NaN       NaN
#      6       15.831398     0.0  0.0  11.937073   17.031408  6.120000
#      8       13.145051     0.0  0.0  11.090986   16.287761  3.908000
#      9       14.181189     0.0  0.0  11.191029   13.848750  5.554286
#      10      12.817128     0.0  0.0  11.021571   13.509000  3.260000
#      11      12.428722     0.0  0.0  11.774866   13.769726  9.015714
#      12      16.065864     0.0  0.0  15.867440   18.033425  5.887143
# 2018 1        9.728371     0.0  0.0   9.485519   10.313380  3.380000
#      2       10.688251     0.0  0.0   9.817050   10.289114  8.304000
#
#                                   RetailTransfers          ... WarehouseSales  \
# ...

# %%
dataretail['RetailSales'].plot(kind = 'line', title='Retail sales throuh time')

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
dataretail['RetailSales'].plot(kind = 'bar', title='Retail sales throuh time')

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
xaxis = dataretail['RetailSales'][['BEER','DUNNAGE','KEGS','LIQUOR','NON-ALCOHOL','REF','STR_SUPPLIES','WINE']]
yaxis = dataretail['RetailTransfers'][['BEER','DUNNAGE','KEGS','LIQUOR','NON-ALCOHOL','REF','STR_SUPPLIES','WINE']]

# %%
for i,j in zip(xaxis,yaxis):
    plt.scatter(xaxis[i],yaxis[j], label = i)
    plt.xlabel("Retail Sales")
    plt.ylabel("Retail Transfers")

plt.legend(loc='upper right')
plt.show();

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
matriz = data[['RetailSales','RetailTransfers','WarehouseSales','ItemType']]
matriz
# Out:
#         RetailSales  RetailTransfers  WarehouseSales ItemType
# 0              0.00              1.0             0.0     WINE
# 1              0.00              1.0             0.0     WINE
# 2              0.00              8.0             0.0   LIQUOR
# 3              0.00              2.0             0.0   LIQUOR
# 4              0.00              4.0             0.0     WINE
# ...             ...              ...             ...      ...
# 128350        66.46             59.0           212.0     BEER
# 128351         9.08              7.0            35.0     BEER
# 128352         0.00              0.0            32.0     KEGS
# 128353         0.00              0.0           -35.0      REF
# 128354         0.00              0.0           -81.0      REF
#
# [128355 rows x 4 columns]

# %%
sns.pairplot(matriz, hue="ItemType")
