# %%
#Import libraries
import pandas as pd
import numpy as np
import re
import folium
import matplotlib.pyplot as plt
import pymongo

# %%
#Checking the Database, which is in my mongoDB
client = pymongo.MongoClient()
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
data = client.companies

# %%
colection = data.companies

# %%
category = list(colection.find({},{"_id":0, "category_code":1}))

# %%
category[29]
# Out:
# {'category_code': 'advertising'}

# %%
category[0]["category_code"]
# Out:
# 'web'

# %%
cat = []
for i in range(len(category)):
    cat.append(category[i]["category_code"])

# %%
#Checking the categories, I noted web is the most commmon one.
set(cat)
# Out:
# {'advertising',
#  'analytics',
#  'automotive',
#  'biotech',
#  'cleantech',
#  'consulting',
#  'design',
#  'ecommerce',
#  'education',
#  'enterprise',
#  'fashion',
#  'finance',
#  'games_video',
#  'government',
#  'hardware',
#  'health',
#  'hospitality',
#  'legal',
#  'local',
#  'manufacturing',
#  'medical',
#  'messaging',
#  'mobile',
#  'music',
#  'nanotech',
#  'network_hosting',
#  'news',
#  'nonprofit',
#  'null',
#  'other',
#  'photo_video',
#  'public_relations',
#  'real_estate',
#  'search',
#  'security',
#  'semiconductor',
#  'social',
#  'software',
#  'sports',
#  'transportation',
#  'travel',
#  'web'}

# %%
fundation = list(colection.find({},{'name':1,"_id":0, "founded_year":1,"category_code":1,"deadpooled_year":1}))

# %%
#We note that we have a big company Data of web. But Im choosing fashion, because I feel is a sector I want to work in, so lets check where this companies are.
fundation
# Out:
# [{'name': 'Wetpaint',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'deadpooled_year': 1},
#  {'name': 'AdventNet',
#   'category_code': 'enterprise',
#   'founded_year': 1996,
#   'deadpooled_year': 2},
#  {'name': 'Zoho',
#   'category_code': 'software',
#   'founded_year': 2005,
#   'deadpooled_year': 3},
#  {'name': 'Digg',
#   'category_code': 'news',
#   'founded_year': 2004,
#   'deadpooled_year': nan},
#  {'name': 'Facebook',
#   'category_code': 'social',
#   'founded_year': 2004,
#   'deadpooled_year': nan},
#  {'name': 'Omnidrive',
#   'category_code': 'network_hosting',
#   'founded_year': 2005,
#   'deadpooled_year': 2008},
#  {'name': 'Postini',
#   'category_code': 'web',
#   'founded_year': 1999,
#   'deadpooled_year': nan},
#  {'name': 'Geni',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'deadpooled_year': nan},
#  {'name': 'Flektor',
#   'category_code': 'games_video',
#   'founded_year': nan,
#   'deadpooled_year': nan},
# ...

# %%
fashion = list(colection.find({},{'name':1,"_id":0, "founded_year":1,"category_code":"fashion","deadpooled_year":1}))

# %%
fashion
# Out:
# [{'name': 'Wetpaint',
#   'founded_year': 2005,
#   'deadpooled_year': 1,
#   'category_code': 'fashion'},
#  {'name': 'AdventNet',
#   'founded_year': 1996,
#   'deadpooled_year': 2,
#   'category_code': 'fashion'},
#  {'name': 'Zoho',
#   'founded_year': 2005,
#   'deadpooled_year': 3,
#   'category_code': 'fashion'},
#  {'name': 'Digg',
#   'founded_year': 2004,
#   'deadpooled_year': nan,
#   'category_code': 'fashion'},
#  {'name': 'Facebook',
#   'founded_year': 2004,
#   'deadpooled_year': nan,
#   'category_code': 'fashion'},
#  {'name': 'Omnidrive',
#   'founded_year': 2005,
#   'deadpooled_year': 2008,
#   'category_code': 'fashion'},
#  {'name': 'Postini',
#   'founded_year': 1999,
#   'deadpooled_year': nan,
#   'category_code': 'fashion'},
#  {'name': 'Geni',
#   'founded_year': 2006,
#   'deadpooled_year': nan,
#   'category_code': 'fashion'},
#  {'name': 'Flektor',
#   'founded_year': nan,
#   'deadpooled_year': nan,
#   'category_code': 'fashion'},
# ...

# %%
#Im choosing the companies that are younger, so Im choosing companies from 2005.

# %%
fashion_founded = list(colection.find({},{'name':1,"_id":0, "founded_year": "2005","category_code":"fashion","deadpooled_year":1}))

# %%
fashion_founded
# Out:
# [{'name': 'Wetpaint',
#   'deadpooled_year': 1,
#   'founded_year': '2005',
#   'category_code': 'fashion'},
#  {'name': 'AdventNet',
#   'deadpooled_year': 2,
#   'founded_year': '2005',
#   'category_code': 'fashion'},
#  {'name': 'Zoho',
#   'deadpooled_year': 3,
#   'founded_year': '2005',
#   'category_code': 'fashion'},
#  {'name': 'Digg',
#   'deadpooled_year': nan,
#   'founded_year': '2005',
#   'category_code': 'fashion'},
#  {'name': 'Facebook',
#   'deadpooled_year': nan,
#   'founded_year': '2005',
#   'category_code': 'fashion'},
#  {'name': 'Omnidrive',
#   'deadpooled_year': 2008,
#   'founded_year': '2005',
#   'category_code': 'fashion'},
#  {'name': 'Postini',
#   'deadpooled_year': nan,
#   'founded_year': '2005',
#   'category_code': 'fashion'},
#  {'name': 'Geni',
#   'deadpooled_year': nan,
#   'founded_year': '2005',
#   'category_code': 'fashion'},
#  {'name': 'Flektor',
#   'deadpooled_year': nan,
#   'founded_year': '2005',
#   'category_code': 'fashion'},
# ...

# %%
#Im noticing some of the data is not well labeled, but Im choosing randomly 5 to check if there are coincidences regarding the location.

# %%
#1
list(colection.find({'name':'Jobvite'},
                {'_id':0, 'number_of_employees':1, 'description':1, 'founded_year':1}))
#San Francisco, California.
# Out:
# [{'number_of_employees': nan,
#   'founded_year': 2003,
#   'description': 'On-demand job recruiting'}]

# %%
#2
list(colection.find({'name':'Jacked'},
                {'_id':0, 'number_of_employees':1, 'description':1, 'founded_year':1}))
#Santa Mónica, California
# Out:
# [{'number_of_employees': 36, 'founded_year': 2006, 'description': 'null'}]

# %%
#3
list(colection.find({'name':'eyeOS'},
                {'_id':0, 'number_of_employees':1, 'description':1, 'founded_year':1}))
#Barcelona, España | But also is not a fashion company.
# Out:
# [{'number_of_employees': nan,
#   'founded_year': 2005,
#   'description': 'Leading Cloud Desktop worldwide. '}]

# %%
#4
list(colection.find({'name':'Blyk'},
                {'_id':0, 'number_of_employees':1, 'description':1, 'founded_year':1}))
#Helsinki, Finlandia
# Out:
# [{'number_of_employees': 100,
#   'founded_year': 2006,
#   'description': 'Mobile Social Networking'}]

# %%
#5
list(colection.find({'name':'Vivox'},
                {'_id':0, 'number_of_employees':1, 'description':1, 'founded_year':1}))
#Framingham, Massachusetts
# Out:
# [{'number_of_employees': nan,
#   'founded_year': 2005,
#   'description': 'Integrated Voice Chat Provider'}]

# %%
#We can see 3 of them are in USA and two of them in California. So Ill pick from California the easist place to move: San Francisco.

# %%
map_a = folium.Map(location=[37.756274, -122.488506], tiles='stamentoner', zoom_start=13)
map_a
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_a.save
# Out:
# <bound method Element.save of <folium.folium.Map object at 0x7fd119c3ddd0>>

# %%
#Im choosing Near the Golden park since around there are a lot of different fashion stores and its a meeting point for the citizens. Im also choosing a house nearby, Im going to check which its closer to subway.

# %%
m = folium.Map(
    location=[37.745595, -122.501407],
    zoom_start=15,
    tiles='Stamen Terrain'
)

# %%
trolley = folium.Marker(
    location=[37.741912, -122.500635],
    tooltip='Stop: Taraval St & 42nd Ave',
    icon=folium.Icon(color="red"))

# %%
company_office = folium.Marker(
    location=[37.742842, -122.501493], 
    tooltip='Office')

# %%
company_office.add_to(map_a)
trolley.add_to(map_a)

map_a
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_a.save
# Out:
# <bound method Element.save of <folium.folium.Map object at 0x7fd119c3ddd0>>
