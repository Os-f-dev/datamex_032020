# %%
import pandas as pd
import numpy as np
import re
import folium
import matplotlib.pyplot as plt
import pymongo

# %%
cliente = pymongo.MongoClient()
cliente
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
database = cliente.companies

# %%
colect = database.companies

# %%
categorias = list(colect.find({},{"_id":0, "category_code":1}))

# %%
categorias[0]
# Out:
# {'category_code': 'web'}

# %%
categorias[0]["category_code"]
# Out:
# 'web'

# %%
category = []
for i in range(len(categorias)):
    category.append(categorias[i]["category_code"])

# %%
set(category)
# Out:
# {'advertising',
#  'analytics',
#  'automotive',
#  'biotech',
#  'cleantech',
#  'consulting',
#  'design',
#  'ecommerce',
#  'education',
#  'enterprise',
#  'fashion',
#  'finance',
#  'games_video',
#  'government',
#  'hardware',
#  'health',
#  'hospitality',
#  'legal',
#  'local',
#  'manufacturing',
#  'medical',
#  'messaging',
#  'mobile',
#  'music',
#  'nanotech',
#  'network_hosting',
#  'news',
#  'nonprofit',
#  'null',
#  'other',
#  'photo_video',
#  'public_relations',
#  'real_estate',
#  'search',
#  'security',
#  'semiconductor',
#  'social',
#  'software',
#  'sports',
#  'transportation',
#  'travel',
#  'web'}

# %%
fundacion = list(colect.find({},{"_id":0, "founded_year":1,"category_code":1,"deadpooled_year":1}))

# %%
fundacion
# Out:
# [{'category_code': 'web', 'founded_year': 2005, 'deadpooled_year': 1},
#  {'category_code': 'enterprise', 'founded_year': 1996, 'deadpooled_year': 2},
#  {'category_code': 'software', 'founded_year': 2005, 'deadpooled_year': 3},
#  {'category_code': 'news', 'founded_year': 2004, 'deadpooled_year': nan},
#  {'category_code': 'social', 'founded_year': 2004, 'deadpooled_year': nan},
#  {'category_code': 'network_hosting',
#   'founded_year': 2005,
#   'deadpooled_year': 2008},
#  {'category_code': 'web', 'founded_year': 1999, 'deadpooled_year': nan},
#  {'category_code': 'web', 'founded_year': 2006, 'deadpooled_year': nan},
#  {'category_code': 'games_video', 'founded_year': nan, 'deadpooled_year': nan},
#  {'category_code': 'web', 'founded_year': 1979, 'deadpooled_year': nan},
#  {'category_code': 'social', 'founded_year': 2006, 'deadpooled_year': nan},
#  {'category_code': 'web', 'founded_year': 2002, 'deadpooled_year': nan},
# ...
