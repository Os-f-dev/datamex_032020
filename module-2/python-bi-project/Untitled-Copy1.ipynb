# %%
import numpy as np
import os
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pymongo 
from pandas.io.json import json_normalize
from folium import plugins
# %matplotlib inline

# %%
cliente=pymongo.MongoClient()  # llamar a la clase MongoClient
cliente
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
cliente.database_names()
# Out:
# <ipython-input-3-0d9b22017567>:1: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
#   cliente.database_names()
# ['Oficinas', 'admin', 'companies', 'config', 'local']

# %%
comp = cliente.companies
comp
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies')

# %%
comp.collection_names()
# Out:
# <ipython-input-5-38e632cb5826>:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   comp.collection_names()
# ['companies']

# %%
comp_colec = comp.companies
comp_colec
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies'), 'companies')

# %%
comp_keys = comp_colec.find({})
comp_keys[0].keys()
# Out:
# dict_keys(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url', 'blog_url', 'blog_feed_url', 'twitter_username', 'category_code', 'number_of_employees', 'founded_year', 'founded_month', 'founded_day', 'deadpooled_year', 'tag_list', 'alias_list', 'email_address', 'phone_number', 'description', 'created_at', 'updated_at', 'overview', 'image', 'products', 'relationships', 'competitions', 'providerships', 'total_money_raised', 'funding_rounds', 'investments', 'acquisition', 'acquisitions', 'offices', 'milestones', 'video_embeds', 'screenshots', 'external_links', 'partners'])

# %%
part_1 = list(comp_colec.find({},{'name':1, 'category_code':1, 'offices':1,},))
part_1
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8a'),
#   'name': 'Wetpaint',
#   'category_code': 'web',
#   'offices': [{'description': '',
#     'address1': '710 - 2nd Avenue',
#     'address2': 'Suite 1100',
#     'zip_code': '98104',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.603122,
#     'longitude': -122.333253},
#    {'description': '',
#     'address1': '270 Lafayette Street',
#     'address2': 'Suite 505',
#     'zip_code': '10012',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7237306,
#     'longitude': -73.9964312}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d8b'),
#   'name': 'AdventNet',
#   'category_code': 'enterprise',
#   'offices': [{'description': 'Headquarters',
#     'address1': '4900 Hopyard Rd.',
#     'address2': 'Suite 310',
#     'zip_code': '94588',
#     'city': 'Pleasanton',
#     'state_code': 'CA',
#     'country_code': 'USA',
# ...

# %%
companies=pd.DataFrame(part_1)
companies.head()
# Out:
#                         _id       name category_code  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint           web
# 1  52cdef7c4bab8bd675297d8b  AdventNet    enterprise
# 2  52cdef7c4bab8bd675297d8c       Zoho      software
# 3  52cdef7c4bab8bd675297d8d       Digg          news
# 4  52cdef7c4bab8bd675297d8e   Facebook        social
#
#                                              offices
# 0  [{'description': '', 'address1': '710 - 2nd Av...
# 1  [{'description': 'Headquarters', 'address1': '...
# 2  [{'description': 'Headquarters', 'address1': '...
# 3  [{'description': None, 'address1': '135 Missis...
# 4  [{'description': 'Headquarters', 'address1': '...

# %%
companies.drop(['_id'], axis=1)
# Out:
#                       name category_code  \
# 0                 Wetpaint           web
# 1                AdventNet    enterprise
# 2                     Zoho      software
# 3                     Digg          news
# 4                 Facebook        social
# ...                    ...           ...
# 18796               Adhunk   advertising
# 18797           AfterLogic      software
# 18798          goBookmaker           web
# 18799  EnteGreat Solutions      software
# 18800            EnteGreat    enterprise
#
#                                                  offices
# 0      [{'description': '', 'address1': '710 - 2nd Av...
# 1      [{'description': 'Headquarters', 'address1': '...
# 2      [{'description': 'Headquarters', 'address1': '...
# 3      [{'description': None, 'address1': '135 Missis...
# 4      [{'description': 'Headquarters', 'address1': '...
# ...                                                  ...
# 18796  [{'description': 'Indian Office', 'address1': ...
# ...

# %%
col_filter = comp_colec.find({'$and':[{'offices':{'$not':{'$size':0}}},
                                             {'category_code':'biotech'}]},
                                    {'_id':0,'name':1,'category_code':1,'offices':1})

# %%
dffilter = pd.DataFrame(col_filter)
dffilter
# Out:
#                  name category_code  \
# 0             23andMe       biotech
# 1           Genentech       biotech
# 2        Nutra Pharma       biotech
# 3       Posit Science       biotech
# 4             Manyeta       biotech
# ..                ...           ...
# 333        OptiMedica       biotech
# 334           NanoInk       biotech
# 335  Chestnut Medical       biotech
# 336       Xray Imatek       biotech
# 337   InSound Medical       biotech
#
#                                                offices
# 0    [{'description': '', 'address1': '2606 Bayshor...
# 1    [{'description': '', 'address1': '', 'address2...
# 2    [{'description': 'Corporate Headquarters', 'ad...
# 3    [{'description': '', 'address1': '77 Geary St'...
# 4    [{'description': 'HQ', 'address1': '1555, boul...
# ..                                                 ...
# 333  [{'description': 'Corporate Headquarters', 'ad...
# 334  [{'description': '', 'address1': '8025 Lamon A...
# ...

# %%
dffilter.isna().sum()
# Out:
# name             0
# category_code    0
# offices          0
# dtype: int64

# %%
json_normalize(dffilter['offices'][0])
# Out:
# <ipython-input-14-d330c5114e56>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   json_normalize(dffilter['offices'][0])
#   description               address1 address2 zip_code           city  \
# 0              2606 Bayshore Parkway             94042  Mountain View
#
#   state_code country_code  latitude  longitude
# 0         CA          USA  37.09024 -95.712891

# %%
bioffices=[pd.json_normalize(i) for i in dffilter['offices']]
bioffices
# Out:
# [  description               address1 address2 zip_code           city  \
#  0              2606 Bayshore Parkway             94042  Mountain View
#
#    state_code country_code  latitude  longitude
#  0         CA          USA  37.09024 -95.712891  ,
#    description address1 address2 zip_code                 city state_code  \
#  0                                         South San Francisco       None
#
#    country_code  latitude  longitude
#  0          USA  37.09024 -95.712891  ,
#                description               address1 address2 zip_code  \
#  0  Corporate Headquarters  2776 University Drive             33065
#
#              city state_code country_code   latitude  longitude
#  0  Coral Springs         FL          USA  26.398866 -80.100609  ,
#    description     address1 address2 zip_code           city state_code  \
#  0              77 Geary St  Ste 303    94108  San Francisco         CA
#
#    country_code latitude longitude
# ...

# %%
primer_registro = bioffices[0]
primer_registro
# Out:
#   description               address1 address2 zip_code           city  \
# 0              2606 Bayshore Parkway             94042  Mountain View
#
#   state_code country_code  latitude  longitude
# 0         CA          USA  37.09024 -95.712891

# %%
primer_nombre = dffilter['name'][0]
primer_nombre
# Out:
# '23andMe'

# %%
primer_registro['Company_name'] = primer_nombre
primer_registro
# Out:
#   description               address1 address2 zip_code           city  \
# 0              2606 Bayshore Parkway             94042  Mountain View
#
#   state_code country_code  latitude  longitude Company_name
# 0         CA          USA  37.09024 -95.712891      23andMe

# %%
lista_nombres =  list(dffilter['name'])

# %%
print(len(lista_nombres), len(dffilter))
# Out:
# 338 338

# %%
zip_nombre_df = list(zip(lista_nombres,dffilter))

# %%
zip_nombre_df[0][1]
# Out:
# 'name'

# %%
for i,item in enumerate(bioffices):
    item["category_code"] = dffilter["category_code"][i]

# %%
long_lat_df = [i[['category_code','country_code','city','latitude','longitude']] for i in bioffices]
long_lat_df[1]
# Out:
#   category_code country_code                 city  latitude  longitude
# 0       biotech          USA  South San Francisco  37.09024 -95.712891

# %%
concat_df = pd.DataFrame()

# %%
pd.concat([long_lat_df[0],long_lat_df[1]])
# Out:
#   category_code country_code                 city  latitude  longitude
# 0       biotech          USA        Mountain View  37.09024 -95.712891
# 0       biotech          USA  South San Francisco  37.09024 -95.712891

# %%
for i in range(len(long_lat_df)):
    concat_df  = pd.concat([concat_df,long_lat_df[i]])

# %%
concat_df.dropna(inplace = True)

# %%
concat_df
# Out:
#    category_code country_code                 city   latitude   longitude
# 0        biotech          USA        Mountain View  37.090240  -95.712891
# 0        biotech          USA  South San Francisco  37.090240  -95.712891
# 0        biotech          USA        Coral Springs  26.398866  -80.100609
# 0        biotech          USA        Santa Barbara  34.424185 -119.704902
# 0        biotech          USA            Cambridge  42.363567  -71.091189
# ..           ...          ...                  ...        ...         ...
# 0        biotech          USA            Ann Arbor  42.307971  -83.692762
# 0        biotech          USA          Santa Clara  37.377798 -121.974454
# 0        biotech          USA               Skokie  42.041574  -87.749253
# 0        biotech          USA           Menlo Park  37.481946 -122.171759
# 0        biotech          USA               Newark  37.512038 -121.998513
#
# [241 rows x 5 columns]

# %%
can=concat_df[concat_df['country_code']=='USA']
can
# Out:
#    category_code country_code                 city   latitude   longitude
# 0        biotech          USA        Mountain View  37.090240  -95.712891
# 0        biotech          USA  South San Francisco  37.090240  -95.712891
# 0        biotech          USA        Coral Springs  26.398866  -80.100609
# 0        biotech          USA        Santa Barbara  34.424185 -119.704902
# 0        biotech          USA            Cambridge  42.363567  -71.091189
# ..           ...          ...                  ...        ...         ...
# 0        biotech          USA            Ann Arbor  42.307971  -83.692762
# 0        biotech          USA          Santa Clara  37.377798 -121.974454
# 0        biotech          USA               Skokie  42.041574  -87.749253
# 0        biotech          USA           Menlo Park  37.481946 -122.171759
# 0        biotech          USA               Newark  37.512038 -121.998513
#
# [202 rows x 5 columns]

# %%
can['city'].value_counts()
# Out:
# San Diego              12
# South San Francisco    12
# Cambridge              10
# New York                6
# La Jolla                5
#                        ..
# Charleston              1
# Malvern                 1
# Chapel Hill             1
# Bedford                 1
# Billerica               1
# Name: city, Length: 118, dtype: int64

# %%
can_1= can[['latitude','longitude','country_code']]
can_1
# Out:
#      latitude   longitude country_code
# 0   37.090240  -95.712891          USA
# 0   37.090240  -95.712891          USA
# 0   26.398866  -80.100609          USA
# 0   34.424185 -119.704902          USA
# 0   42.363567  -71.091189          USA
# ..        ...         ...          ...
# 0   42.307971  -83.692762          USA
# 0   37.377798 -121.974454          USA
# 0   42.041574  -87.749253          USA
# 0   37.481946 -122.171759          USA
# 0   37.512038 -121.998513          USA
#
# [202 rows x 3 columns]

# %%
canmap=folium.Map([37.090240,-95.712891], zoom_start=4)
canmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
canmap.add_child(plugins.HeatMap(can_1, radius=20))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.CircleMarker(location=[37.090240,-95.712891], radius= 10 , icon =folium.Icon()).add_to(mapa)

# %%
mapa.save('mapa_eu.html')

# %%
m = folium.Map(
    location=[45.372, -121.6972],
    zoom_start=12,
    tiles='Stamen Terrain'
)
folium.Marker([37.090240,-95.712891], popup='<strong>Mt. Hood Meadows</strong>', tooltip='tooltip').add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa_l = folium.Map(location=[39.38, -97.92], min_lat= 30, max_lat=120, min_lon=30, max_lon=120,
                    max_bounds=True)

# %%
can_1.reset_index(inplace = True)

# %%
can_1.drop('index',inplace = True, axis = 1)
# Out:
# /Users/joel/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
can_1.head(2)
# Out:
#    latitude  longitude country_code
# 0  37.09024 -95.712891          USA
# 1  37.09024 -95.712891          USA

# %%
for i in range(len(can_1)):
    folium.Marker([can_1.loc[i,'latitude'], can_1.loc[i,'longitude']], 
                  tooltip = can_1.loc[i,'country_code'], popup=  can_1.loc[i,'country_code']).add_to(mapa_l)
mapa_l
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# WHERE IS THE BEST PLACE TO STABLISH A BIOTECH ENTERPRICE?
#
#
# FOR CEO MR. RICK SANCHEZ
#
# MR. SANCHEZ I WAS BUSY ALL WEEKEND SEARCHING THE RICKFORMATION ABOUT WHERE TO STABLISH OUR RICKIOTECH ENTERPRICE IN AMERICA, AND THE RICKREALITY IS RICKDICULOUS.
#
# AT FIRST WE ARE ABLE TO SEE THAT THERE´RE NOT MANY BIOTECH ENTERPRICES IN AMERICA, WE CAN SEE KIND THE RICKFOMATION ON THE DATAFRAMES ABOVE, IN FACT THE PLAN JERRY SMITH HAD ABOUT STABLISHING ON PHOENIX ARIZONE BOARD WASN´T THAT BAD AT ALL(MY MISTAKE),DO YOU KNOW THERE ARE NOT BIOTECH ENTERPRICES IN MEXICO AT ALL?(THATS RICKDICULUOS), THE ONLY PROBLEM I CAN SEE IN THIS SITUATION ABOUT STABLISHIN IN MEXICO STATE CHICHUAHUA IS THE POLITICAL STATEMENT OF SOMETHING CALLED AUSTERIDA OF OUR NOT VERY GOOD STUPID FRIEND LOPEZ OBRADOR.
#
# BUT IF WE CAN USE THE PORTAL GUN TO TURN HIM INTO A PICKLE, THA WOULD SAVE ALL OF OUR PROBLEMS.
#
# SINCERELY YOURS OHHHHHHH WEEEEE MR. PUPPY BUTHOLE
