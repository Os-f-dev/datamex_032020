# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
kmeans = KMeans(n_clusters = 8)
kmeans.fit(X)

y1_pred= kmeans.predict(X)

silhouette_score(X, y1_pred)
# Out:
# 0.5398971441034137

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters = 5)
kmeans.fit(X)

y2_pred= kmeans.predict(X)

silhouette_score(X, y2_pred)
# Out:
# 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters = 3)
kmeans.fit(X)

y3_pred= kmeans.predict(X)

silhouette_score(X, y3_pred)
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
modelo = KMeans()

visual = KElbowVisualizer(modelo, k = (1,10), metric='distortion')

visual.fit(X)

visual.poof();

# %%
modelo = KMeans()

visual = KElbowVisualizer(modelo, k = (2,12), metric='silhouette')

visual.fit(X)

visual.poof();

# %%
modelo =KMeans()

visual = KElbowVisualizer(modelo, metric = 'calinski_harabasz', k = (2,12))

visual.fit(X)

visual.poof();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn.cluster import AgglomerativeClustering as AC

# %%
modelo2 =AC()

visual2 = KElbowVisualizer(modelo2, k = (1,10), metric = 'distortion')

visual2.fit(X)

visual2.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
import seaborn as sns

# %%
kmeans = KMeans(n_clusters = 3)
kmeans.fit(X)

y_pred= kmeans.predict(X)

matrix = pd.DataFrame(X, columns=X.columns)
matrix['pred']= y_pred

# %%
sns.pairplot(matrix, hue="pred")

# %%
pd.plotting.scatter_matrix(matrix)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E482A070>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E3229460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E2F15670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E46312E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4849BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E5F03340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E5F03430>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E5EE1C10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E74FEAF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7536280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E755EA00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E75951C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E75BF940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E75E8160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E761D880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E76460A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E767C7C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E76A5F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E76DB700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7706E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E773C640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7764DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E779A580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E77C3D00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E77F84C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7823C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7858400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7881B80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E78B9340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E78E1AC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7916280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E793EA00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E79761C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E79A0940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E79C9160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E79FE880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7A270A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7A5E7C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7A87F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7ABD700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7AE7E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7B1D640>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7B44DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7B7A580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7BA3D00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7BD94C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7C03C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7C38400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7C62B80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7C9A340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7CC2AC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7CF9280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7D22A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7D581C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7D81940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7DAB160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7DDF880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7E080A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7E3F7C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7E67F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7E9D700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7EC6E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7EFC640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7F25DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7F5B580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7F87D00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7FBC4C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E7FE6C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E801C400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8044B80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8079340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E80A1AC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E80D8280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8102A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E81381C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8162940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E818B160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E81C0880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E81E90A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E821F7C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8246F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8280700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E82A8E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E82DE640>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8307DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E833D580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8365D00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E839C4C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E83C5C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E83FC400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8424B80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E845D340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8484AC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E84BB280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E84E2A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E85171C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8542940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E856D160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E85A1880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E85C90A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E86017C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E862AF40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8661700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E868AE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E86C0640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E86E9DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E871E580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8746D00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E877C4C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E87A5C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E87DC400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8804B80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E883D340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8864AC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E889C280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E88C4A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E88FB1C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8923940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E894E160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8982880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E89AB0A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E89E17C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8A0BF40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8A41700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8A69E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8A9F640>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8AC8DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8B00580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8B28D00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8B5F4C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8B89C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8BBE400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8BE5B80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8C1D340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8C44AC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8C7B280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8CA3A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8CDB1C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8D05940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8D2E160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8D63910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8D8D130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8DC2850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8DECFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8E22790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8E4DF10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8E826D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8EA9E50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8EDF610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8F08D90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8F3E550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E8F68CD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E9F6C490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E9F97C10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E9FCD3D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E9FF6B50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193EA02D310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193EA054A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193EA08E250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193EA0B69D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193EA0EA190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193EA114910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E33EE2E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E2802070>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4795B20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193DF8D0820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E314E4F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E49D8490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4A068E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4A32D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4A6C1C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4A97610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4AC3A60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4AF0EB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4B2C340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4B57790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4B84BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4BB20D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4BE94C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4C15910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4C45D60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4C7D1F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4CA8640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4CD5A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4D03EE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4D3B370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4D677C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4D94C10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4DC1100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4DFA4F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4E27940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4E53D90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4E85E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4EB9640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4EE4DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000193E4F18580>]],
#       dtype=object)

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

# %%
modelo= PCA(n_components = 2).fit_transform(X)

# %%
df =pd.DataFrame(modelo, columns =['pca1','pca2'])

# %%
df['pred']= y_pred

# %%
sns.scatterplot(df['pca1'],df['pca2'], hue = df['pred'])

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE

# %%
X_e = TSNE(n_components=2).fit_transform(X)

sns.scatterplot(X_e[:,0],X_e[:,1], hue = df['pred'])
